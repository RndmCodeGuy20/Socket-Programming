# %%
import matplotlib.pyplot as plt

img = plt.imread('img.jpg')
plt.imshow(img)
plt.plot()
# Out:
# []

# %%
img = str(img)
img
# Out:
# '[[[38 39 44]\n  [38 39 44]\n  [39 38 43]\n  ...\n  [35 40 46]\n  [35 40 46]\n  [35 40 46]]\n\n [[36 39 46]\n  [36 39 46]\n  [38 38 46]\n  ...\n  [35 40 46]\n  [35 40 46]\n  [35 40 46]]\n\n [[32 40 51]\n  [32 41 50]\n  [33 40 50]\n  ...\n  [35 40 46]\n  [35 40 46]\n  [35 40 46]]\n\n ...\n\n [[32 32 32]\n  [33 33 33]\n  [33 33 33]\n  ...\n  [32 32 32]\n  [32 32 32]\n  [32 32 32]]\n\n [[32 32 32]\n  [33 33 33]\n  [33 33 33]\n  ...\n  [32 32 32]\n  [32 32 32]\n  [32 32 32]]\n\n [[32 32 32]\n  [33 33 33]\n  [33 33 33]\n  ...\n  [32 32 32]\n  [32 32 32]\n  [32 32 32]]]'
